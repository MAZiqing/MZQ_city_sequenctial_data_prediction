# %% [markdown]
# # 数据分析

# %% [markdown]
# ## 整合数据成一个DataFrame

# %%
import os
import pdb
import numpy as np
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt
from pylab import mpl
from tqdm import tqdm
from sklearn import preprocessing

# %%
root_1 = '../流量'
root_2 = '15个流量计水量数据'
file_list = os.listdir('../流量/15个流量计水量数据')

# %%
def str_to_timestamp(x):
    x = datetime.strptime(x, '%Y-%m-%d %H:%M')
    return int(datetime.timestamp(x))
def timestamp_to_datetime(x):
    return datetime.fromtimestamp(x)
def normalize(df):
    # Create x, where x the 'scores' column's values as floats
    x = df.values.astype(float)

    # Create a minimum and maximum processor object
    min_max_scaler = preprocessing.MinMaxScaler()

    # Create an object to transform the data to fit minmax processor
    x_scaled = min_max_scaler.fit_transform(x)

    # Run the normalizer on the dataframe
    df_normalized = pd.DataFrame(x_scaled, columns=df.columns, index=df.index)
    return df_normalized

# %%
file = file_list[0]
df_i = pd.read_excel(os.path.join(root_1, root_2, file))

# %%
df_i.head(3)
df_i.tail(3)
# Out:
#                      时间       累计流量    用水量      反向流量
# 59471  2019-08-25 23:15  4992519.0  156.0  210415.0
# 59472  2019-08-25 23:30  4992675.0  115.0  210415.0
# 59473  2019-08-25 23:45  4992790.0    NaN  210415.0

# %%
file_list
# Out:
# ['527中吴大道.xlsx',
#  '552叶汤路.xlsx',
#  '625 港区大道.xlsx',
#  '637 新338省道.xlsx',
#  '666 常戚路.xlsx',
#  '723 青洋北路.xlsx',
#  '725 东方东路.xlsx',
#  '727 玉龙路.xlsx',
#  '730 江春路.xlsx',
#  '750 通江路.xlsx',
#  '785 长江路龙城大道.xlsx',
#  '794  龙江路.xlsx',
#  '795 西赢里.xlsx',
#  '800 健身路.xlsx',
#  '811 延陵西路.xlsx']

# %%
start_time_str = '2017-01-01 00:00'
end_time_str = '2019-08-25 00:00'
start_timestamp = str_to_timestamp(start_time_str)
end_timestamp = str_to_timestamp(end_time_str)
time_step = 60*15
df = pd.DataFrame(index=list(range(start_timestamp, end_timestamp, time_step)))
for file in file_list:
    dfi = pd.read_excel(os.path.join(root_1, root_2, file))
    dfi['timestamp'] = dfi['时间'].apply(str_to_timestamp)
    dfi['用水量'] = dfi['累计流量'].diff()
    # pdb.set_trace()
    dfi.drop(columns=['时间','累计流量','反向流量'], inplace=True)
    dfi = dfi.set_index('timestamp')
    dfi = dfi.rename(columns={'用水量': file[0:-5]+'Q'})
    # pdb.set_trace()
    df = df.join(dfi)

# %%
df.head(5)
# Out:
#             527中吴大道Q  552叶汤路Q  625 港区大道Q  637 新338省道Q  666 常戚路Q  723 青洋北路Q  \
# 1483200000       NaN      NaN        NaN          NaN       NaN        NaN
# 1483200900       2.8    172.0      146.0        156.0      63.0       38.0
# 1483201800       2.9    167.0      151.0        154.0      60.0       36.0
# 1483202700       2.7    164.0      153.0        147.0      62.0       36.0
# 1483203600       2.8    162.0      163.0        146.0      58.0       37.0
#
#             725 东方东路Q  727 玉龙路Q  730 江春路Q  750 通江路Q  785 长江路龙城大道Q  794  龙江路Q  \
# 1483200000        NaN       NaN       NaN       NaN           NaN        NaN
# 1483200900        0.0     109.0       0.0      84.0         286.0      261.0
# 1483201800        0.0     107.0       0.0      45.0         283.0      262.0
# 1483202700        0.0     107.0       0.0       5.0         270.0      263.0
# 1483203600        0.0     101.0       0.0       7.0         266.0      247.0
#
#             795 西赢里Q  800 健身路Q  811 延陵西路Q
# 1483200000       NaN       NaN        NaN
# 1483200900       0.0       NaN        0.0
# 1483201800       0.0      45.0        0.0
# 1483202700       0.0       NaN        0.0
# 1483203600       0.0      43.0        0.0

# %% [markdown]
# ## 数据集已经建立'15流量_dataset.csv'

# %%
df['datetime'] = df.index
df['datetime'] = df['datetime'].apply(timestamp_to_datetime)
df = df.set_index('datetime')
# df.to_csv(os.path.join(root_1, '15流量_dataset.csv'))

# %% [markdown]
# ## 清洗前的数据

# %%
df = pd.read_csv(os.path.join(root_1, '15流量_dataset.csv'), index_col=0)

# %%
df.head(3)
# Out:
#                      527中吴大道Q  552叶汤路Q  625 港区大道Q  637 新338省道Q  666 常戚路Q  \
# datetime
# 2017-01-01 00:00:00       NaN      NaN        NaN          NaN       NaN
# 2017-01-01 00:15:00       2.8    172.0      146.0        156.0      63.0
# 2017-01-01 00:30:00       2.9    167.0      151.0        154.0      60.0
#
#                      723 青洋北路Q  725 东方东路Q  727 玉龙路Q  730 江春路Q  750 通江路Q  \
# datetime
# 2017-01-01 00:00:00        NaN        NaN       NaN       NaN       NaN
# 2017-01-01 00:15:00       38.0        0.0     109.0       0.0      84.0
# 2017-01-01 00:30:00       36.0        0.0     107.0       0.0      45.0
#
#                      785 长江路龙城大道Q  794  龙江路Q  795 西赢里Q  800 健身路Q  811 延陵西路Q
# datetime
# 2017-01-01 00:00:00           NaN        NaN       NaN       NaN        NaN
# 2017-01-01 00:15:00         286.0      261.0       0.0       NaN        0.0
# 2017-01-01 00:30:00         283.0      262.0       0.0      45.0        0.0

# %%
# 作图
column_num = df.shape[1]
plt.figure(figsize=(15, column_num * 3))
for index, column in enumerate(list(df.columns)):
    plt.subplot(column_num, 1, index+1)
    df[column].plot()
plt.show()

# %% [markdown]
# ## 清洗后的数据

# %%
for column in list(df.columns):
    demand_min = df[column].quantile(0.05)
    demand_max = df[column].quantile(0.98)
    mask1 = df[column] < demand_min
    mask2 = df[column] > demand_max
    df[column][mask1 | mask2] = np.nan
df = df.interpolate()
df = df.interpolate(limit_direction='backward')

# %%
column_num = df.shape[1]
mpl.rcParams['font.sans-serif'] = ['FangSong']  # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
plt.figure(figsize=(15, column_num * 3), facecolor='w')
for index, column in enumerate(list(df.columns)):
    plt.subplot(column_num, 1, index+1)
    df[column].plot()
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
column_list_bad = ['527中吴大道Q', '723 青洋北路Q', '725 东方东路Q',
                   '730 江春路Q', '750 通江路Q', '795 西赢里Q', '811 延陵西路Q']
df2 = df.drop(columns=column_list_bad)
df2 = normalize(df2)
        

column_num = df2.shape[1]
mpl.rcParams['font.sans-serif'] = ['FangSong']  # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题
plt.figure(figsize=(15, column_num * 3), facecolor='w')
for index, column in enumerate(list(df2.columns)):
    plt.subplot(column_num, 1, index+1)
    df2[column].plot()
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
# plt.figure(figsize=(15, 4))
df2.iloc[0:200,0:3].plot()
df2.iloc[0:300,3:6].plot()
df2.iloc[0:100,6:8].plot()
# plt.show()

# %%
df2.corr()
# Out:
#                552叶汤路Q  625 港区大道Q  637 新338省道Q  666 常戚路Q  727 玉龙路Q  \
# 552叶汤路Q       1.000000   0.641492     0.899406  0.809844  0.895711
# 625 港区大道Q     0.641492   1.000000     0.558233  0.617429  0.675065
# 637 新338省道Q   0.899406   0.558233     1.000000  0.751942  0.803021
# 666 常戚路Q      0.809844   0.617429     0.751942  1.000000  0.838053
# 727 玉龙路Q      0.895711   0.675065     0.803021  0.838053  1.000000
# 785 长江路龙城大道Q  0.872030   0.665127     0.792070  0.832730  0.934547
# 794  龙江路Q     0.888526   0.703001     0.780943  0.837084  0.959889
# 800 健身路Q      0.790024   0.586282     0.796530  0.780299  0.833701
#
#               785 长江路龙城大道Q  794  龙江路Q  800 健身路Q
# 552叶汤路Q           0.872030   0.888526  0.790024
# 625 港区大道Q         0.665127   0.703001  0.586282
# 637 新338省道Q       0.792070   0.780943  0.796530
# 666 常戚路Q          0.832730   0.837084  0.780299
# 727 玉龙路Q          0.934547   0.959889  0.833701
# 785 长江路龙城大道Q      1.000000   0.947624  0.873610
# 794  龙江路Q         0.947624   1.000000  0.852479
# 800 健身路Q          0.873610   0.852479  1.000000

# %% [markdown]
# ## Arima 预测

# %%
df_arima = pd.read_csv(os.path.join(root_1, '15流量_dataset.csv'), index_col=0)
df_arima = df_arima['552叶汤路Q'].values
df_arima
# Out:
# array([ nan, 172., 167., ..., 259., 247., 239.])

# %%
from pmdarima.arima import auto_arima as pm
import numpy as np
from matplotlib import pyplot as plt
train = df_arima[1:1000]
test = df_arima[1000:1300]
arima = pm.auto_arima(train, error_action='ignore', trace=1,
                      seasonal=True, m=12)
pred = arima.predict(n_periods=test.shape[0])
